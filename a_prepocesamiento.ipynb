# %% [markdown]
# <a href="https://colab.research.google.com/github/AleAguirreM/LEA3_Health/blob/main/a_prepocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 ### para leer imagenes jpeg
### pip install opencv-python
from matplotlib import pyplot as plt ## para gráfciar imágnes
#import _funciones as fn#### funciones personalizadas, carga de imágenes
import joblib ### para descargar array
import sys

# %%
pip install opencv-python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sys.path.append('/content/drive/MyDrive')

# %%
import _funciones as fn

# %%
img_normal = cv2.imread('/content/drive/MyDrive/TB_Chest_Radiography_Database/train/Normal/Normal-1.png')
img_infeccion = cv2.imread('/content/drive/MyDrive/TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-1.png')

# %%
plt.imshow(img_normal)
plt.title('normal')
plt.show()

# %%
imgnormal_r= cv2.resize(img_normal ,(300,300))
plt.imshow(imgnormal_r)
plt.title('Normal')
plt.show()
np.prod(imgnormal_r.shape)
# Out:
# 270000

# %%
img_normal.shape
# Out:
# (512, 512, 3)

# %%
img_normal.max() ### máximo valor de intensidad en un pixel
# Out:
# 237

# %%
img_normal.min() ### mínimo valor de intensidad en un pixel
# Out:
# 0

# %%
plt.imshow(img_infeccion)
plt.title('normal')
plt.show()

# %%
imginfeccion_r= cv2.resize(img_infeccion ,(100,100))
plt.imshow(imginfeccion_r)
plt.title('Normal')
plt.show()
np.prod(imginfeccion_r.shape)
# Out:
# 30000

# %%
################################################################
######## Código para cargar todas las imágenes #############
####### reducir su tamaño y convertir en array ################
################################################################

width = 100 #tamaño para reescalar imágen
num_classes = 2 #clases variable respuesta
trainpath = '/content/drive/MyDrive/TB_Chest_Radiography_Database/train/'
testpath = '/content/drive/MyDrive/TB_Chest_Radiography_Database/test/'

x_train, y_train= fn.img2data(trainpath) #Run in train
x_test, y_test = fn.img2data(testpath) #Run in test




#### convertir salidas a numpy array ####
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

x_train.shape


np.prod(x_train[1].shape)
y_train.shape


x_test.shape
y_test.shape
# Out:
# ...
# 100%|██████████| 2800/2800 [02:55<00:00, 15.97it/s]
# (0,)
